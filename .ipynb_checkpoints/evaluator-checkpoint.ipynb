# %%
import os
import argparse
import pickle

from joblib import Parallel, delayed
import scipy
import torch
from tqdm import tqdm

from evaluator.trajnet_evaluator import trajnet_evaluate
from evaluator.write_utils import load_test_datasets, preprocess_test, write_predictions
from slstm.lstm import LSTMPredictor

# %%
def predict_scene(predictor, model_name, paths, scene_goal, args):
    """For each scene, get model predictions"""
    paths = preprocess_test(paths, args.obs_length)
#     if 'sf_opt' in model_name:
#         predictions = predictor(paths, sf_params=[0.5, 5.0, 0.3], n_predict=args.pred_length, obs_length=args.obs_length) ## optimal sf_params (no collision constraint) [0.5, 1.0, 0.1],
    
    if  ('sf' in model_name) or ('orca' in model_name) or ('kf' in model_name):
        predictions = predictor(paths, n_predict=args.pred_length, obs_length=args.obs_length)
    elif 'lstm' in model_name:
        """For each scene, get model predictions"""
        predictions = predictor(paths, scene_goal, n_predict=args.pred_length, obs_length=args.obs_length, modes=args.modes, args=args)
    else:
        raise NotImplementedError
    return predictions

# def predict_scene(predictor, model_name, paths, scene_goal, args):
#     """For each scene, get model predictions"""
#     paths = preprocess_test(paths, args.obs_length)
#     predictions = predictor(paths, scene_goal, n_predict=args.pred_length, obs_length=args.obs_length, modes=args.modes, args=args)
#     return predictions

# %%
def load_predictor(model_name, model, device='cpu'):
    """Loading the APPROPRIATE model"""
    if 'kf' in model_name:
        print("Kalman")
        from classical.kalman import predict_kf as predictor
    elif 'sf' in model_name:
        print("Social Force")
        from classical.socialforce import predict_sf as predictor
    elif 'lstm' in model_name:
        print("s-lstm")
        predictor = LSTMPredictor.load(model)
        predictor.model.to(torch.device(device))
    return predictor

# %%
def get_predictions(args):
    """Get model predictions for each test scene and write the predictions in appropriate folders"""
    ## List of .json file inside the args.path (waiting to be predicted by the testing model)
    datasets = sorted([f.split('.')[-2] for f in os.listdir(args.path.replace('_pred', '')) if not f.startswith('.') and f.endswith('.ndjson')])

    ## Handcrafted Baselines (if included)
    if args.kf:
        args.output.append('/kf.pkl')
    if args.sf:
        args.output.append('/sf.pkl')


    ## Extract Model names from arguments and create its own folder in 'test_pred' for storing predictions
    ## WARNING: If Model predictions already exist from previous run, this process SKIPS WRITING
    for model in args.output:
        model_name = model.split('/')[-1].replace('.pkl', '')
        model_name = model_name + '_modes' + str(args.modes)

        ## Check if model predictions already exist
        if not os.path.exists(args.path):
            os.makedirs(args.path)
        if not os.path.exists(args.path + model_name):
            os.makedirs(args.path + model_name)
        else:
            print('Predictions corresponding to {} already exist.'.format(model_name))
            print('Loading the saved predictions')
            continue

        print("Model Name: ", model_name)
        predictor = load_predictor(model_name, model)
        goal_flag = False

        # Iterate over test datasets
        for dataset in datasets:
            # Load dataset
            dataset_name, scenes, scene_goals = load_test_datasets(dataset, goal_flag, args)

        
            # Get all predictions in parallel. Faster!
            scenes = scenes[:args.len]
            scenes = tqdm(scenes)

            pred_list = Parallel(n_jobs=4)(delayed(predict_scene)(predictor, model_name, paths, scene_goal, args)
                                            for (_, _, paths), scene_goal in zip(scenes, scene_goals))
            
            # Write all predictions
            write_predictions(pred_list, scenes, model_name, dataset_name, args)

# %%
# def load_predictor(model, device='cpu'):
#     """Loading the APPROPRIATE model"""
#     predictor = LSTMPredictor.load(model)
#     predictor.model.to(torch.device(device))
#     return predictor


# def get_predictions(args):
#     """Get model predictions for each test scene and write the predictions in appropriate folders"""
#     ## List of .json file inside the args.path (waiting to be predicted by the testing model)
#     datasets = sorted([f.split('.')[-2] for f in os.listdir(args.path.replace('_pred', '')) if not f.startswith('.') and f.endswith('.ndjson')])

#     ## Extract Model names from arguments and create its own folder in 'test_pred' for storing predictions
#     ## WARNING: If Model predictions already exist from previous run, this process SKIPS WRITING
#     for model in args.output:
#         model_name = model.split('/')[-1].replace('.pkl', '')
#         model_name = model_name + '_modes' + str(args.modes)

#         ## Check if model predictions already exist
#         if not os.path.exists(args.path):
#             os.makedirs(args.path)
#         if not os.path.exists(args.path + model_name):
#             os.makedirs(args.path + model_name)
#         else:
#             print('Predictions corresponding to {} already exist.'.format(model_name))
#             print('Loading the saved predictions')
#             continue

#         print("Model Name: ", model_name)
#         predictor = load_predictor(model)
#         goal_flag = predictor.model.goal_flag

#         # Iterate over test datasets
#         for dataset in datasets:
#             # Load dataset
#             dataset_name, scenes, scene_goals = load_test_datasets(dataset, goal_flag, args)
#             scenes = scenes[:1000]
#             # Get all predictions in parallel. Faster!
#             scenes = tqdm(scenes)
#             pred_list = Parallel(n_jobs=4)(delayed(predict_scene)(predictor, model_name, paths, scene_goal, args)
#                                             for (_, _, paths), scene_goal in zip(scenes, scene_goals))
            
#             # Write all predictions
#             write_predictions(pred_list, scenes, model_name, dataset_name, args)

# %%
class Args:
    def __init__(self):
        self.path = 'try1'
        self.output = []
        self.obs_length = 25
        self.pred_length = 25
        self.write_only = False
        self.disable_collision = False
        self.labels = None
        self.normalize_scene = False
        self.modes = 2
        self.sf = False
#         self.lstm = False
        self.kf = False
        self.len = 1000

args = Args()

# %%
def main(args):
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--path', default='trajdata',
#                         help='directory of data to test')
#     parser.add_argument('--output', nargs='+',
#                         help='relative path to saved model')
#     parser.add_argument('--obs_length', default=25, type=int,
#                         help='observation length')
#     parser.add_argument('--pred_length', default=25, type=int,
#                         help='prediction length')
#     parser.add_argument('--write_only', action='store_true',
#                         help='disable writing new files')
#     parser.add_argument('--disable-collision', action='store_true',
#                         help='disable collision metrics')
#     parser.add_argument('--labels', required=False, nargs='+',
#                         help='labels of models')
#     parser.add_argument('--normalize_scene', action='store_true',
#                         help='augment scenes')
#     parser.add_argument('--modes', default=1, type=int,
#                         help='number of modes to predict')
#     parser.add_argument('--sf', action='store_true',
#                         help='consider socialforce in evaluation')
#     parser.add_argument('--orca', action='store_true',
#                         help='consider orca in evaluation')
#     parser.add_argument('--kf', action='store_true',
#                         help='consider kalman in evaluation')
#     parser.add_argument('--cv', action='store_true',
#                         help='consider constant velocity in evaluation')
#     args = parser.parse_args()

    scipy.seterr('ignore')

#     args.output = []
    ## assert length of output models is not None
    if (not args.sf) and (not args.orca) and (not args.kf) and (not args.cv):
        assert 'No handcrafted baseline mentioned'

    args.output = args.output if args.output is not None else []
    
    args.path = 'DATA_BLOCK/' + args.path + '/test_pred/'

    ## Writes to Test_pred
    ## Does NOT overwrite existing predictions if they already exist ###
    get_predictions(args)
    if args.write_only: # For submission to AICrowd.
        print("Predictions written in test_pred folder")
        exit()
    ## Evaluate using TrajNet++ evaluator
    trajnet_evaluate(args)

# %%
if __name__ == '__main__':
    args.output = ['OUTPUT_BLOCK/try1/lstm_social_None.pkl']
    args.sf = 1
    args.kf = 1

    main(args)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13116\3847908439.py:31: DeprecationWarning: scipy.seterr is deprecated and will be removed in SciPy 2.0.0, use numpy.seterr instead
#   scipy.seterr('ignore')
# Model Name:  kf_modes1
# Kalman
# Dataset Name:  18_tracks.ndjson
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [13:55<00:00,  1.67s/it]
# Model Name:  sf_modes1
# Social Force
# Dataset Name:  18_tracks.ndjson
#  32%|█████████████████████████▌                                                      | 160/500 [21:26<45:27,  8.02s/it]C:\Users\Administrator\anaconda3\envs\pytorch\lib\site-packages\joblib\externals\loky\process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [1:04:54<00:00,  7.79s/it]
# kf_modes1
# ['18_tracks.ndjson']
# pred_datasets:  ['DATA_BLOCK/try1/test_pred/kf_modes1/18_tracks.ndjson']
# true_datasets:  ['DATA_BLOCK/try1/test_private/18_tracks.ndjson']
# sf_modes1
# ['18_tracks.ndjson']
# pred_datasets:  ['DATA_BLOCK/try1/test_pred/sf_modes1/18_tracks.ndjson']
# true_datasets:  ['DATA_BLOCK/try1/test_private/18_tracks.ndjson']

# %%
if __name__ == '__main__':
    args.output = ['OUTPUT_BLOCK/try1/lstm_social_None.pkl']
    args.sf = 1
    args.kf = 1
    
    main(args)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14412\2670270029.py:31: DeprecationWarning: scipy.seterr is deprecated and will be removed in SciPy 2.0.0, use numpy.seterr instead
#   scipy.seterr('ignore')
# Model Name:  lstm_social_None_modes2
# s-lstm
# Dataset Name:  18_tracks.ndjson
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [03:47<00:00,  4.39it/s]
# Model Name:  kf_modes2
# Kalman
# Dataset Name:  18_tracks.ndjson
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [24:42<00:00,  1.48s/it]
# Model Name:  sf_modes2
# Social Force
# Dataset Name:  18_tracks.ndjson
#  31%|████████████████████████                                                     | 312/1000 [38:31<1:25:16,  7.44s/it]C:\Users\Administrator\anaconda3\envs\pytorch\lib\site-packages\joblib\externals\loky\process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# 100%|████████████████████████████████████████████████████████████████████████████| 1000/1000 [2:06:03<00:00,  7.56s/it]
# lstm_social_None_modes2
# ['18_tracks.ndjson']
# pred_datasets:  ['DATA_BLOCK/try1/test_pred/lstm_social_None_modes2/18_tracks.ndjson']
# true_datasets:  ['DATA_BLOCK/try1/test_private/18_tracks.ndjson']
# kf_modes2
# ['18_tracks.ndjson']
# pred_datasets:  ['DATA_BLOCK/try1/test_pred/kf_modes2/18_tracks.ndjson']
# true_datasets:  ['DATA_BLOCK/try1/test_private/18_tracks.ndjson']
# sf_modes2
# ['18_tracks.ndjson']
# pred_datasets:  ['DATA_BLOCK/try1/test_pred/sf_modes2/18_tracks.ndjson']
# true_datasets:  ['DATA_BLOCK/try1/test_private/18_tracks.ndjson']
